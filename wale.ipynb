# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\AMADI DOMNIC U\Desktop\python\data.csv')

# %%
data.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
# ...

# %%
#no 1 : statiscal description of the numerical columns

data.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
#no 2 :top 10 movies with highest revenue

data.sort_values(['revenue'], ascending=False)[['revenue','original_title']].head(10)
# Out:
#          revenue                                original_title
# 1386  2781505847                                        Avatar
# 3     2068178225                  Star Wars: The Force Awakens
# 5231  1845034188                                       Titanic
# 4361  1519557910                                  The Avengers
# 0     1513528810                                Jurassic World
# 4     1506249360                                     Furious 7
# 14    1405035767                       Avengers: Age of Ultron
# 3374  1327817822  Harry Potter and the Deathly Hallows: Part 2
# 5422  1274219009                                        Frozen
# 5425  1215439994                                    Iron Man 3

# %%
data.sort_values(['revenue'], ascending=False)[['revenue','original_title']].head(10).plot.bar(x='original_title', y='revenue')
plt.ylabel('Revenue in billions')
plt.title('top 10 movies with highest revenue')
# Out:
# Text(0.5, 1.0, 'top 10 movies with highest revenue')

# %%
#no 3 : movies with no information on revenue
data.isnull().sum()
#since revenue has a null value of 0,therefore all movies have information on revenue
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
#no 4 : top 10 cast with highest feature

data['cast'].str.split('|',expand=True).stack().value_counts().head(15)
# Out:
# Robert De Niro       72
# Samuel L. Jackson    71
# Bruce Willis         62
# Nicolas Cage         61
# Michael Caine        53
# Robin Williams       51
# John Cusack          50
# John Goodman         49
# Morgan Freeman       49
# Liam Neeson          48
# Susan Sarandon       48
# Julianne Moore       47
# Alec Baldwin         47
# Tom Hanks            46
# Gene Hackman         46
# dtype: int64

# %%
data['cast'].str.split('|',expand=True).stack().value_counts().head(10).plot.bar()
plt.xlabel('cast',fontsize=15)
plt.title('top 10 cast with highest feature')
# Out:
# Text(0.5, 1.0, 'top 10 cast with highest feature')

# %%
#top 10 ended with Liam Neeson but Susan Sarandon has the same count with Liam Neeson,
#in our analysis do we now say Susan Sarandon is not included among the top 10?

# %%
#no 5 :top 10 genres across various movies

data['genres'].str.split('|',expand=True).stack().value_counts().head(10)
# Out:
# Drama              4761
# Comedy             3793
# Thriller           2908
# Action             2385
# Romance            1712
# Horror             1637
# Adventure          1471
# Crime              1355
# Family             1231
# Science Fiction    1230
# dtype: int64

# %%
data['genres'].str.split('|',expand=True).stack().value_counts().head(10).plot.bar()
plt.xlabel('Genres',fontsize=15)
plt.title('top 10 genres across various movies')
# Out:
# Text(0.5, 1.0, 'top 10 genres across various movies')

# %%
#no 6 : top 10 companies in terms of movie production

data['production_companies'].value_counts().head(10)
# Out:
# Paramount Pictures                        156
# Universal Pictures                        133
# Warner Bros.                               84
# Walt Disney Pictures                       76
# Columbia Pictures                          72
# Metro-Goldwyn-Mayer (MGM)                  72
# New Line Cinema                            61
# Touchstone Pictures                        51
# 20th Century Fox                           50
# Twentieth Century Fox Film Corporation     49
# Name: production_companies, dtype: int64

# %%
data['production_companies'].value_counts().head(10).plot.bar()
plt.xlabel('Production Companies',fontsize=15)
plt.title(' top 10 companies in terms of movie production')
# Out:
# Text(0.5, 1.0, ' top 10 companies in terms of movie production')

# %%
#no 7 : there is no question for this number

# %%
#no 8 :top 10 directors in terms of movie production

data.value_counts('director').head(10)
# Out:
# director
# Woody Allen          45
# Clint Eastwood       34
# Steven Spielberg     29
# Martin Scorsese      29
# Ridley Scott         23
# Steven Soderbergh    22
# Ron Howard           22
# Joel Schumacher      21
# Brian De Palma       20
# Wes Craven           19
# dtype: int64

# %%
data.value_counts('director').head(10).plot.bar()
plt.title('Top 10 directors')
# Out:
# Text(0.5, 1.0, 'Top 10 directors')

# %%
#no 9 :changes in revenue/budget across the years

data.groupby('release_year')[['revenue','budget']].sum().sort_values('revenue',ascending=False)
# Out:
#                   revenue      budget
# release_year
# 2015          26762450518  7596547557
# 2013          24703633017  9236038361
# 2012          24668428824  8274084052
# 2014          24331150183  7923990138
# 2011          23695591578  9018153652
# 2009          22180170559  8594084056
# 2010          21959998545  9385001006
# 2008          19431695138  7781262597
# 2007          19411668670  7635569004
# 2004          16793822618  7170340222
# 2005          16516835108  7343284349
# 2006          16275739385  7306185300
# 2003          15138243542  6239857694
# 2002          14643618528  5894640255
# 2001          13410083139  5641944000
# 1999          11355712579  5765235106
# 2000          10978701012  5752700000
# 1997          10655173234  4751086675
# 1998           9493174938  4499660000
# 1995           9156341160  2865884377
# 1996           8311492279  3687042051
# 1994           7095429177  2229207032
# 1993           6955151167  1779628653
# ...

# %%
data.groupby('release_year')[['revenue','budget']].sum().plot.bar()
plt.title('changes in revenue/budget across the years')
# Out:
# Text(0.5, 1.0, 'changes in revenue/budget across the years')

# %%
data.groupby('release_year')[['revenue','budget']].sum().plot(y=['revenue','budget'], kind='line')
plt.title('changes in revenue/budget across the years')
# Out:
# Text(0.5, 1.0, 'changes in revenue/budget across the years')

# %%
#no 10 :number of release movies across the years

# %%
data.groupby('release_year')[['original_title']].count()
# Out:
#               original_title
# release_year
# 1960                      32
# 1961                      31
# 1962                      32
# 1963                      34
# 1964                      42
# 1965                      35
# 1966                      46
# 1967                      40
# 1968                      39
# 1969                      31
# 1970                      41
# 1971                      55
# 1972                      40
# 1973                      55
# 1974                      47
# 1975                      44
# 1976                      47
# 1977                      57
# 1978                      65
# 1979                      57
# 1980                      78
# 1981                      82
# 1982                      81
# 1983                      80
# 1984                     105
# 1985                     109
# 1986                     121
# 1987                     125
# 1988                     145
# 1989                     137
# ...

# %%
data.groupby('release_year')[['original_title']].count().plot.bar()
plt.title('number of release movies across the years')
# Out:
# Text(0.5, 1.0, 'number of release movies across the years')

# %%
#no 11:average popularity/average vote based on release month

data['month'] = pd.DatetimeIndex(data['release_date']).month

# %%
data.groupby('month')[['popularity','vote_average']].mean()
# Out:
#        popularity  vote_average
# month
# 1        0.460574      5.870620
# 2        0.589931      5.918524
# 3        0.642752      5.926974
# 4        0.562475      5.875533
# 5        0.749997      5.967985
# 6        0.800755      6.012092
# 7        0.747678      5.928411
# 8        0.584363      5.840087
# 9        0.564820      6.068069
# 10       0.613168      5.959844
# 11       0.755466      6.062654
# 12       0.750784      6.189442

# %%
data.groupby('month')[['popularity', 'vote_average']].mean().plot(y=['popularity','vote_average'], kind='line')
plt.title('average popularity/average vote based on release month')
# Out:
# Text(0.5, 1.0, 'average popularity/average vote based on release month')

# %%
data.groupby('month')[['popularity', 'vote_average']].mean().plot(kind='bar')
plt.title('average popularity/average vote based on release month')
# Out:
# Text(0.5, 1.0, 'average popularity/average vote based on release month')
